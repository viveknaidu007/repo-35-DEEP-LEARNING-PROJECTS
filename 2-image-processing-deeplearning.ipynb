# %%
#image data processing

# %%
'''
topics
1.reading an iamge file and converting it to numpy array
2.resizing an image
3.RGB to Grayscale convertion
'''

# %%
#libraries that can be used for image processing
'''
matplotlib.image
pillow
opencv(cv2)
'''

# %%
#importing the image from matplolib library

import matplotlib.image as im
import matplotlib.pyplot as plt

# %%
#loading the image

img = im.imread("puppy-care-guide-for-new-parents.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)

#(width, height , RGB iamge(thast y it showed 3) )
# Out:
# (1365, 2048, 3)

# %%
print(img) #this is how image is showed and converted into its numpy arrays
# Out:
# [[[147 182   0]
#   [147 182   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[146 181   0]
#   [146 181   0]
#   [147 182   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[145 180   0]
#   [145 180   0]
#   [145 180   0]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  ...
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]
#
#  [[ 76  69  25]
#   [ 76  69  25]
#   [ 75  68  24]
#   ...
#   [135 106  38]
#   [135 106  38]
#   [135 106  38]]]

# %%
#displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %%
#resizing the image using the pillow library

from PIL import Image

# %%
img = Image.open("puppy-care-guide-for-new-parents.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1365>

# %%
#now we ressizing only 200*200

img = Image.open("puppy-care-guide-for-new-parents.jpg")
img_resized = img.resize((200,200))

# %%
#we can also save the image
img_resized.save('dog_image_resized.jpg')

# %%
#now we can disolay the image from numpy array

img_res = im.imread("dog_image_resized.jpg")
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
#converting RGB images to grayscale image using opencv

# %%
import cv2

# %%
img = cv2.imread("dog_image_resized.jpg")

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
gray_scale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray_scale_img.shape
# Out:
# (200, 200)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
#
#
# **from google.colab.patches import cv2_imshow**

# %%
cv2.imshow("imge",gray_scale_img)

'''
cv2.waitKey(0)
cv2.destroyAllWindows()
'''
